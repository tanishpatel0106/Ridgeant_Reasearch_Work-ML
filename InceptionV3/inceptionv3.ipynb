# %% [markdown]
# # Inception V3

# %% [markdown]
# Inception V3 is a deep convolutional neural network (CNN) architecture that was developed by Google researchers as an evolution of the original Inception model. It was introduced in 2015 and has since become a widely used and influential model in the field of computer vision.
#
# The main goal of Inception V3 is to improve the efficiency and performance of CNNs by addressing some of the limitations of previous architectures. One of the key ideas behind Inception V3 is the use of "Inception modules" that allow for multiple filter sizes to be processed in parallel at each layer of the network. This enables the model to capture features at different scales and resolutions, leading to better representation of complex visual patterns.
#
# Here are some notable features and design principles of Inception V3:
#
# 1. Inception modules: The core building blocks of Inception V3 are the Inception modules, which consist of a set of parallel convolutional layers with different filter sizes (1x1, 3x3, 5x5) and pooling operations. By using multiple filter sizes, the model can capture information at different spatial scales.
# 2. Dimensionality reduction: In order to reduce the computational cost and the number of parameters, Inception V3 incorporates 1x1 convolutions as a way to reduce the dimensions of the input feature maps before applying larger convolutions. This helps to maintain the richness of information while reducing the computational burden.
# 3. Auxiliary classifiers: Inception V3 introduces auxiliary classifiers at intermediate layers of the network. These classifiers have two purposes: they provide additional gradients during training to combat the vanishing gradient problem and they act as regularizers that help improve generalization.
# 4. Factorization: Inception V3 incorporates a factorization strategy called "bottleneck layers." This involves using 1x1 convolutions to reduce the number of input channels before applying more computationally expensive operations. This helps to reduce the number of parameters and allows the model to capture complex features more efficiently.
# 5. Pre-training: Inception V3 is typically pre-trained on large-scale image classification datasets such as ImageNet. The pre-training phase involves training the network on a large collection of labeled images to learn general visual representations. This pre-trained model can then be fine-tuned on specific tasks or datasets.
#
# Overall, Inception V3 is known for its strong performance on a variety of computer vision tasks, including image classification, object detection, and image segmentation. It strikes a balance between accuracy and computational efficiency, making it a popular choice for many real-world applications.

# %% [markdown]
# The Inception V3 architecture is a deep convolutional neural network (CNN) model that builds upon the original Inception model. It was developed by Google researchers for image classification tasks and has achieved impressive results on various computer vision challenges. Here's a detailed description of the Inception V3 architecture:
#
# 1. Input Layer: The input to the network is an RGB image typically of size 299x299 pixels.
# 2. Stem: The stem module serves as the initial building block of the network. It consists of several convolutional layers with different filter sizes, max pooling, and batch normalization operations. The purpose of the stem is to extract low-level features from the input image.
# 3. Inception Modules: The core component of Inception V3 is the Inception module. These modules are stacked on top of each other to form the bulk of the network. Each Inception module is designed to capture features at different scales by performing parallel convolutions with different filter sizes.
#     a. 1x1 Convolution: The module begins with a 1x1 convolution that acts as a bottleneck layer, reducing the number of input channels.
#     b. 3x3 Convolution: This branch consists of a 3x3 convolutional layer that processes the input with a medium-sized receptive field.
#     c. 5x5 Convolution: Another branch employs a 5x5 convolutional layer to capture information with a larger receptive field.
#     d. Max Pooling: The module also includes a max pooling layer with a stride of 1x1 to capture spatial information.
#     e. 1x1 Convolution (Dimension Reduction): To further reduce the computational complexity, a 1x1 convolutional layer is employed to reduce the number of channels before applying larger convolutions.
#     f. Concatenation: The outputs from all branches are concatenated along the channel dimension to create the module's output.
# 4. Reduction Modules: Inception V3 incorporates reduction modules to decrease the spatial dimensions and increase the number of channels. These modules are introduced periodically in the network to facilitate information flow and reduce computational costs.
# 5. Auxiliary Classifiers: Inception V3 includes auxiliary classifiers at intermediate layers. These auxiliary classifiers are additional branches that perform classification tasks and provide regularization during training. They help combat the vanishing gradient problem and improve generalization.
# 6. Fully Connected Layers: After several Inception modules, the feature maps are fed into fully connected layers, which serve as the final classification layers of the network. The fully connected layers are followed by a softmax activation to produce the class probabilities.
#
# Overall, the Inception V3 architecture leverages the power of parallel convolutions with different filter sizes, dimensionality reduction, auxiliary classifiers, and factorization to efficiently capture and represent features at various scales. It strikes a balance between model size, computational complexity, and accuracy, making it a popular choice for image classification and related tasks.

# %% [markdown]
# ## Defining the Inception V3 Architecture

# %% [markdown]
# ### Importing Required Dependencies

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import concatenate
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining Inception Blocks

# %% [markdown]
# #### Defining a Convolutional with Batch Normalisation Block

# %%
def conv_with_Batch_Normalisation(prev_layer, nbr_kernels, filter_Size, strides =(1,1), padding = 'same'):
    x = tf.keras.layers.Conv2D(filters=nbr_kernels, kernel_size = filter_Size, strides=strides , padding=padding)(prev_layer)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(activation='relu')(x)
    return x

# %% [markdown]
# #### Defining a Stem Block

# %%
def StemBlock(prev_layer):
    x = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 32, filter_Size=(3,3) , strides=(2,2))
    x = conv_with_Batch_Normalisation(x, nbr_kernels = 32, filter_Size=(3,3))
    x = conv_with_Batch_Normalisation(x, nbr_kernels = 64, filter_Size=(3,3))
    x = tf.keras.layers.MaxPool2D(pool_size=(3,3) , strides=(2,2)) (x)
    x = conv_with_Batch_Normalisation(x, nbr_kernels = 80, filter_Size=(1,1))
    x = conv_with_Batch_Normalisation(x, nbr_kernels = 192, filter_Size=(3,3))
    x = tf.keras.layers.MaxPool2D(pool_size=(3,3) , strides=(2,2)) (x)
    return x

# %% [markdown]
# #### Defining Inception Block A

# %%
def InceptionBlock_A(prev_layer, nbr_kernels):
    branch1 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 64, filter_Size = (1,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels=96, filter_Size=(3,3))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels=96, filter_Size=(3,3))
    branch2 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels=48, filter_Size=(1,1))
    branch2 = conv_with_Batch_Normalisation(branch2, nbr_kernels=64, filter_Size=(3,3))
    branch3 = tf.keras.layers.AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding='same') (prev_layer)
    branch3 = conv_with_Batch_Normalisation(branch3, nbr_kernels = nbr_kernels, filter_Size = (1,1))
    branch4 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels=64, filter_Size=(1,1))
    output = concatenate([branch1 , branch2 , branch3 , branch4], axis=3)
    
    return output

# %% [markdown]
# #### Defining Inception Block B

# %%
def InceptionBlock_B(prev_layer, nbr_kernels):
    branch1 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = nbr_kernels, filter_Size = (1,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = nbr_kernels, filter_Size = (7,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = nbr_kernels, filter_Size = (1,7))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = nbr_kernels, filter_Size = (7,1))    
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 192, filter_Size = (1,7))
    branch2 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = nbr_kernels, filter_Size = (1,1))
    branch2 = conv_with_Batch_Normalisation(branch2, nbr_kernels = nbr_kernels, filter_Size = (1,7))
    branch2 = conv_with_Batch_Normalisation(branch2, nbr_kernels = 192, filter_Size = (7,1))
    branch3 = tf.keras.layers.AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding ='same') (prev_layer)
    branch3 = conv_with_Batch_Normalisation(branch3, nbr_kernels = 192, filter_Size = (1,1))
    branch4 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 192, filter_Size = (1,1))
    output = concatenate([branch1 , branch2 , branch3 , branch4], axis = 3)
    return output

# %% [markdown]
# #### Defining Inception Block C

# %%
def InceptionBlock_C(prev_layer):
    branch1 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 448, filter_Size = (1,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 384, filter_Size = (3,3))
    branch1_1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 384, filter_Size = (1,3))    
    branch1_2 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 384, filter_Size = (3,1))
    branch1 = concatenate([branch1_1 , branch1_2], axis = 3)
    branch2 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 384, filter_Size = (1,1))
    branch2_1 = conv_with_Batch_Normalisation(branch2, nbr_kernels = 384, filter_Size = (1,3))
    branch2_2 = conv_with_Batch_Normalisation(branch2, nbr_kernels = 384, filter_Size = (3,1))
    branch2 = concatenate([branch2_1 , branch2_2], axis = 3)
    branch3 = tf.keras.layers.AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding='same')(prev_layer)
    branch3 = conv_with_Batch_Normalisation(branch3, nbr_kernels = 192, filter_Size = (1,1))
    branch4 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 320, filter_Size = (1,1))
    output = concatenate([branch1 , branch2 , branch3 , branch4], axis = 3)
    return output

# %% [markdown]
# #### Defining Reduction Block A

# %%
def ReductionBlock_A(prev_layer):
    branch1 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 64, filter_Size = (1,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 96, filter_Size = (3,3))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 96, filter_Size = (3,3) , strides=(2,2) ) #, padding='valid'
    branch2 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 384, filter_Size=(3,3) , strides=(2,2) )
    branch3 = tf.keras.layers.MaxPool2D(pool_size=(3,3) , strides=(2,2) , padding='same')(prev_layer)
    output = concatenate([branch1 , branch2 , branch3], axis = 3)
    return output

# %% [markdown]
# #### Defining Reduction Block B

# %%
def ReductionBlock_B(prev_layer):
    branch1 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 192, filter_Size = (1,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 192, filter_Size = (1,7))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 192, filter_Size = (7,1))
    branch1 = conv_with_Batch_Normalisation(branch1, nbr_kernels = 192, filter_Size = (3,3) , strides=(2,2) , padding = 'valid')
    branch2 = conv_with_Batch_Normalisation(prev_layer, nbr_kernels = 192, filter_Size = (1,1) )
    branch2 = conv_with_Batch_Normalisation(branch2, nbr_kernels = 320, filter_Size = (3,3) , strides=(2,2) , padding='valid' )
    branch3 = tf.keras.layers.MaxPool2D(pool_size=(3,3) , strides=(2,2) )(prev_layer)
    output = concatenate([branch1 , branch2 , branch3], axis = 3)
    return output

# %% [markdown]
# #### Defining Auxiliary Classifier

# %%
def auxiliary_classifier(prev_Layer):
    x = tf.keras.layers.AveragePooling2D(pool_size=(5,5) , strides=(3,3)) (prev_Layer)
    x = conv_with_Batch_Normalisation(x, nbr_kernels = 128, filter_Size = (1,1))
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(units = 768, activation='relu') (x)
    x = tf.keras.layers.Dropout(rate = 0.2) (x)
    x = tf.keras.layers.Dense(units = 34, activation='softmax') (x)
    return x

# %% [markdown]
# #### Defining the Inception V3 Architecture

# %%
def InceptionV3():
    input_layer = tf.keras.layers.Input(shape=(299,299,3))
    x = StemBlock(input_layer)
    x = InceptionBlock_A(prev_layer = x, nbr_kernels = 32)
    x = InceptionBlock_A(prev_layer = x, nbr_kernels = 64)
    x = InceptionBlock_A(prev_layer = x, nbr_kernels = 64)
    x = ReductionBlock_A(prev_layer = x)
    x = InceptionBlock_B(prev_layer = x, nbr_kernels = 128)
    x = InceptionBlock_B(prev_layer = x, nbr_kernels = 160)
    x = InceptionBlock_B(prev_layer = x, nbr_kernels = 160)
    x = InceptionBlock_B(prev_layer = x, nbr_kernels = 192)
    Aux = auxiliary_classifier(prev_Layer = x)
    x = ReductionBlock_B(prev_layer = x)
    x = InceptionBlock_C(prev_layer = x)
    x = InceptionBlock_C(prev_layer = x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(units=2048, activation='relu') (x)
    x = tf.keras.layers.Dropout(rate = 0.2) (x)
    x = tf.keras.layers.Dense(units=1000, activation='softmax') (x)
    model = tf.keras.models.Model(inputs = input_layer , outputs = [x , Aux] , name = 'Inception-V3')
    return model

# %% [markdown]
# ### Defining the Inception Model

# %% [markdown]
# #### Defining the Instance of the Inception Model

# %%
model = InceptionV3()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "Inception-V3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_729 (Conv2D)            (None, 150, 150, 32  896         ['input_12[0][0]']
#                                 )
#
#  batch_normalization_729 (Batch  (None, 150, 150, 32  128        ['conv2d_729[0][0]']
#  Normalization)                 )
#
#  activation_729 (Activation)    (None, 150, 150, 32  0           ['batch_normalization_729[0][0]']
#                                 )
#
#  conv2d_730 (Conv2D)            (None, 150, 150, 32  9248        ['activation_729[0][0]']
#                                 )
#
#  batch_normalization_730 (Batch  (None, 150, 150, 32  128        ['conv2d_730[0][0]']
#  Normalization)                 )
#
#  activation_730 (Activation)    (None, 150, 150, 32  0           ['batch_normalization_730[0][0]']
#                                 )
#
#  conv2d_731 (Conv2D)            (None, 150, 150, 64  18496       ['activation_730[0][0]']
#                                 )
#
#  batch_normalization_731 (Batch  (None, 150, 150, 64  256        ['conv2d_731[0][0]']
#  Normalization)                 )
#
#  activation_731 (Activation)    (None, 150, 150, 64  0           ['batch_normalization_731[0][0]']
#                                 )
#
#  max_pooling2d_34 (MaxPooling2D  (None, 74, 74, 64)  0           ['activation_731[0][0]']
#  )
#
#  conv2d_732 (Conv2D)            (None, 74, 74, 80)   5200        ['max_pooling2d_34[0][0]']
#
#  batch_normalization_732 (Batch  (None, 74, 74, 80)  320         ['conv2d_732[0][0]']
#  Normalization)
#
#  activation_732 (Activation)    (None, 74, 74, 80)   0           ['batch_normalization_732[0][0]']
#
#  conv2d_733 (Conv2D)            (None, 74, 74, 192)  138432      ['activation_732[0][0]']
#
#  batch_normalization_733 (Batch  (None, 74, 74, 192)  768        ['conv2d_733[0][0]']
#  Normalization)
#
#  activation_733 (Activation)    (None, 74, 74, 192)  0           ['batch_normalization_733[0][0]']
#
#  max_pooling2d_35 (MaxPooling2D  (None, 36, 36, 192)  0          ['activation_733[0][0]']
#  )
#
#  conv2d_734 (Conv2D)            (None, 36, 36, 64)   12352       ['max_pooling2d_35[0][0]']
#
#  batch_normalization_734 (Batch  (None, 36, 36, 64)  256         ['conv2d_734[0][0]']
#  Normalization)
#
#  activation_734 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_734[0][0]']
#
#  conv2d_735 (Conv2D)            (None, 36, 36, 96)   55392       ['activation_734[0][0]']
#
#  conv2d_737 (Conv2D)            (None, 36, 36, 48)   9264        ['max_pooling2d_35[0][0]']
#
#  batch_normalization_735 (Batch  (None, 36, 36, 96)  384         ['conv2d_735[0][0]']
#  Normalization)
#
#  batch_normalization_737 (Batch  (None, 36, 36, 48)  192         ['conv2d_737[0][0]']
#  Normalization)
#
#  activation_735 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_735[0][0]']
#
#  activation_737 (Activation)    (None, 36, 36, 48)   0           ['batch_normalization_737[0][0]']
#
#  average_pooling2d_80 (AverageP  (None, 36, 36, 192)  0          ['max_pooling2d_35[0][0]']
#  ooling2D)
#
#  conv2d_736 (Conv2D)            (None, 36, 36, 96)   83040       ['activation_735[0][0]']
#
#  conv2d_738 (Conv2D)            (None, 36, 36, 64)   27712       ['activation_737[0][0]']
#
#  conv2d_739 (Conv2D)            (None, 36, 36, 32)   6176        ['average_pooling2d_80[0][0]']
#
#  conv2d_740 (Conv2D)            (None, 36, 36, 64)   12352       ['max_pooling2d_35[0][0]']
#
#  batch_normalization_736 (Batch  (None, 36, 36, 96)  384         ['conv2d_736[0][0]']
#  Normalization)
#
#  batch_normalization_738 (Batch  (None, 36, 36, 64)  256         ['conv2d_738[0][0]']
#  Normalization)
#
#  batch_normalization_739 (Batch  (None, 36, 36, 32)  128         ['conv2d_739[0][0]']
#  Normalization)
#
#  batch_normalization_740 (Batch  (None, 36, 36, 64)  256         ['conv2d_740[0][0]']
#  Normalization)
#
#  activation_736 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_736[0][0]']
#
#  activation_738 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_738[0][0]']
#
#  activation_739 (Activation)    (None, 36, 36, 32)   0           ['batch_normalization_739[0][0]']
#
#  activation_740 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_740[0][0]']
#
#  concatenate_93 (Concatenate)   (None, 36, 36, 256)  0           ['activation_736[0][0]',
#                                                                   'activation_738[0][0]',
#                                                                   'activation_739[0][0]',
#                                                                   'activation_740[0][0]']
#
#  conv2d_741 (Conv2D)            (None, 36, 36, 64)   16448       ['concatenate_93[0][0]']
#
#  batch_normalization_741 (Batch  (None, 36, 36, 64)  256         ['conv2d_741[0][0]']
#  Normalization)
#
#  activation_741 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_741[0][0]']
#
#  conv2d_742 (Conv2D)            (None, 36, 36, 96)   55392       ['activation_741[0][0]']
#
#  conv2d_744 (Conv2D)            (None, 36, 36, 48)   12336       ['concatenate_93[0][0]']
#
#  batch_normalization_742 (Batch  (None, 36, 36, 96)  384         ['conv2d_742[0][0]']
#  Normalization)
#
#  batch_normalization_744 (Batch  (None, 36, 36, 48)  192         ['conv2d_744[0][0]']
#  Normalization)
#
#  activation_742 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_742[0][0]']
#
#  activation_744 (Activation)    (None, 36, 36, 48)   0           ['batch_normalization_744[0][0]']
#
#  average_pooling2d_81 (AverageP  (None, 36, 36, 256)  0          ['concatenate_93[0][0]']
#  ooling2D)
#
#  conv2d_743 (Conv2D)            (None, 36, 36, 96)   83040       ['activation_742[0][0]']
#
#  conv2d_745 (Conv2D)            (None, 36, 36, 64)   27712       ['activation_744[0][0]']
#
#  conv2d_746 (Conv2D)            (None, 36, 36, 64)   16448       ['average_pooling2d_81[0][0]']
#
#  conv2d_747 (Conv2D)            (None, 36, 36, 64)   16448       ['concatenate_93[0][0]']
#
#  batch_normalization_743 (Batch  (None, 36, 36, 96)  384         ['conv2d_743[0][0]']
#  Normalization)
#
#  batch_normalization_745 (Batch  (None, 36, 36, 64)  256         ['conv2d_745[0][0]']
#  Normalization)
#
#  batch_normalization_746 (Batch  (None, 36, 36, 64)  256         ['conv2d_746[0][0]']
#  Normalization)
#
#  batch_normalization_747 (Batch  (None, 36, 36, 64)  256         ['conv2d_747[0][0]']
#  Normalization)
#
#  activation_743 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_743[0][0]']
#
#  activation_745 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_745[0][0]']
#
#  activation_746 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_746[0][0]']
#
#  activation_747 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_747[0][0]']
#
#  concatenate_94 (Concatenate)   (None, 36, 36, 288)  0           ['activation_743[0][0]',
#                                                                   'activation_745[0][0]',
#                                                                   'activation_746[0][0]',
#                                                                   'activation_747[0][0]']
#
#  conv2d_748 (Conv2D)            (None, 36, 36, 64)   18496       ['concatenate_94[0][0]']
#
#  batch_normalization_748 (Batch  (None, 36, 36, 64)  256         ['conv2d_748[0][0]']
#  Normalization)
#
#  activation_748 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_748[0][0]']
#
#  conv2d_749 (Conv2D)            (None, 36, 36, 96)   55392       ['activation_748[0][0]']
#
#  conv2d_751 (Conv2D)            (None, 36, 36, 48)   13872       ['concatenate_94[0][0]']
#
#  batch_normalization_749 (Batch  (None, 36, 36, 96)  384         ['conv2d_749[0][0]']
#  Normalization)
#
#  batch_normalization_751 (Batch  (None, 36, 36, 48)  192         ['conv2d_751[0][0]']
#  Normalization)
#
#  activation_749 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_749[0][0]']
#
#  activation_751 (Activation)    (None, 36, 36, 48)   0           ['batch_normalization_751[0][0]']
#
#  average_pooling2d_82 (AverageP  (None, 36, 36, 288)  0          ['concatenate_94[0][0]']
#  ooling2D)
#
#  conv2d_750 (Conv2D)            (None, 36, 36, 96)   83040       ['activation_749[0][0]']
#
#  conv2d_752 (Conv2D)            (None, 36, 36, 64)   27712       ['activation_751[0][0]']
#
#  conv2d_753 (Conv2D)            (None, 36, 36, 64)   18496       ['average_pooling2d_82[0][0]']
#
#  conv2d_754 (Conv2D)            (None, 36, 36, 64)   18496       ['concatenate_94[0][0]']
#
#  batch_normalization_750 (Batch  (None, 36, 36, 96)  384         ['conv2d_750[0][0]']
#  Normalization)
#
#  batch_normalization_752 (Batch  (None, 36, 36, 64)  256         ['conv2d_752[0][0]']
#  Normalization)
#
#  batch_normalization_753 (Batch  (None, 36, 36, 64)  256         ['conv2d_753[0][0]']
#  Normalization)
#
#  batch_normalization_754 (Batch  (None, 36, 36, 64)  256         ['conv2d_754[0][0]']
#  Normalization)
#
#  activation_750 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_750[0][0]']
#
#  activation_752 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_752[0][0]']
#
#  activation_753 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_753[0][0]']
#
#  activation_754 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_754[0][0]']
#
#  concatenate_95 (Concatenate)   (None, 36, 36, 288)  0           ['activation_750[0][0]',
#                                                                   'activation_752[0][0]',
#                                                                   'activation_753[0][0]',
#                                                                   'activation_754[0][0]']
#
#  conv2d_755 (Conv2D)            (None, 36, 36, 64)   18496       ['concatenate_95[0][0]']
#
#  batch_normalization_755 (Batch  (None, 36, 36, 64)  256         ['conv2d_755[0][0]']
#  Normalization)
#
#  activation_755 (Activation)    (None, 36, 36, 64)   0           ['batch_normalization_755[0][0]']
#
#  conv2d_756 (Conv2D)            (None, 36, 36, 96)   55392       ['activation_755[0][0]']
#
#  batch_normalization_756 (Batch  (None, 36, 36, 96)  384         ['conv2d_756[0][0]']
#  Normalization)
#
#  activation_756 (Activation)    (None, 36, 36, 96)   0           ['batch_normalization_756[0][0]']
#
#  conv2d_757 (Conv2D)            (None, 18, 18, 96)   83040       ['activation_756[0][0]']
#
#  conv2d_758 (Conv2D)            (None, 18, 18, 384)  995712      ['concatenate_95[0][0]']
#
#  batch_normalization_757 (Batch  (None, 18, 18, 96)  384         ['conv2d_757[0][0]']
#  Normalization)
#
#  batch_normalization_758 (Batch  (None, 18, 18, 384)  1536       ['conv2d_758[0][0]']
#  Normalization)
#
#  activation_757 (Activation)    (None, 18, 18, 96)   0           ['batch_normalization_757[0][0]']
#
#  activation_758 (Activation)    (None, 18, 18, 384)  0           ['batch_normalization_758[0][0]']
#
#  max_pooling2d_36 (MaxPooling2D  (None, 18, 18, 288)  0          ['concatenate_95[0][0]']
#  )
#
#  concatenate_96 (Concatenate)   (None, 18, 18, 768)  0           ['activation_757[0][0]',
#                                                                   'activation_758[0][0]',
#                                                                   'max_pooling2d_36[0][0]']
#
#  conv2d_759 (Conv2D)            (None, 18, 18, 128)  98432       ['concatenate_96[0][0]']
#
#  batch_normalization_759 (Batch  (None, 18, 18, 128)  512        ['conv2d_759[0][0]']
#  Normalization)
#
#  activation_759 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_759[0][0]']
#
#  conv2d_760 (Conv2D)            (None, 18, 18, 128)  114816      ['activation_759[0][0]']
#
#  batch_normalization_760 (Batch  (None, 18, 18, 128)  512        ['conv2d_760[0][0]']
#  Normalization)
#
#  activation_760 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_760[0][0]']
#
#  conv2d_761 (Conv2D)            (None, 18, 18, 128)  114816      ['activation_760[0][0]']
#
#  conv2d_764 (Conv2D)            (None, 18, 18, 128)  98432       ['concatenate_96[0][0]']
#
#  batch_normalization_761 (Batch  (None, 18, 18, 128)  512        ['conv2d_761[0][0]']
#  Normalization)
#
#  batch_normalization_764 (Batch  (None, 18, 18, 128)  512        ['conv2d_764[0][0]']
#  Normalization)
#
#  activation_761 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_761[0][0]']
#
#  activation_764 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_764[0][0]']
#
#  conv2d_762 (Conv2D)            (None, 18, 18, 128)  114816      ['activation_761[0][0]']
#
#  conv2d_765 (Conv2D)            (None, 18, 18, 128)  114816      ['activation_764[0][0]']
#
#  batch_normalization_762 (Batch  (None, 18, 18, 128)  512        ['conv2d_762[0][0]']
#  Normalization)
#
#  batch_normalization_765 (Batch  (None, 18, 18, 128)  512        ['conv2d_765[0][0]']
#  Normalization)
#
#  activation_762 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_762[0][0]']
#
#  activation_765 (Activation)    (None, 18, 18, 128)  0           ['batch_normalization_765[0][0]']
#
#  average_pooling2d_83 (AverageP  (None, 18, 18, 768)  0          ['concatenate_96[0][0]']
#  ooling2D)
#
#  conv2d_763 (Conv2D)            (None, 18, 18, 192)  172224      ['activation_762[0][0]']
#
#  conv2d_766 (Conv2D)            (None, 18, 18, 192)  172224      ['activation_765[0][0]']
#
#  conv2d_767 (Conv2D)            (None, 18, 18, 192)  147648      ['average_pooling2d_83[0][0]']
#
#  conv2d_768 (Conv2D)            (None, 18, 18, 192)  147648      ['concatenate_96[0][0]']
#
#  batch_normalization_763 (Batch  (None, 18, 18, 192)  768        ['conv2d_763[0][0]']
#  Normalization)
#
#  batch_normalization_766 (Batch  (None, 18, 18, 192)  768        ['conv2d_766[0][0]']
#  Normalization)
#
#  batch_normalization_767 (Batch  (None, 18, 18, 192)  768        ['conv2d_767[0][0]']
#  Normalization)
#
#  batch_normalization_768 (Batch  (None, 18, 18, 192)  768        ['conv2d_768[0][0]']
#  Normalization)
#
#  activation_763 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_763[0][0]']
#
#  activation_766 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_766[0][0]']
#
#  activation_767 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_767[0][0]']
#
#  activation_768 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_768[0][0]']
#
#  concatenate_97 (Concatenate)   (None, 18, 18, 768)  0           ['activation_763[0][0]',
#                                                                   'activation_766[0][0]',
#                                                                   'activation_767[0][0]',
#                                                                   'activation_768[0][0]']
#
#  conv2d_769 (Conv2D)            (None, 18, 18, 160)  123040      ['concatenate_97[0][0]']
#
#  batch_normalization_769 (Batch  (None, 18, 18, 160)  640        ['conv2d_769[0][0]']
#  Normalization)
#
#  activation_769 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_769[0][0]']
#
#  conv2d_770 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_769[0][0]']
#
#  batch_normalization_770 (Batch  (None, 18, 18, 160)  640        ['conv2d_770[0][0]']
#  Normalization)
#
#  activation_770 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_770[0][0]']
#
#  conv2d_771 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_770[0][0]']
#
#  conv2d_774 (Conv2D)            (None, 18, 18, 160)  123040      ['concatenate_97[0][0]']
#
#  batch_normalization_771 (Batch  (None, 18, 18, 160)  640        ['conv2d_771[0][0]']
#  Normalization)
#
#  batch_normalization_774 (Batch  (None, 18, 18, 160)  640        ['conv2d_774[0][0]']
#  Normalization)
#
#  activation_771 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_771[0][0]']
#
#  activation_774 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_774[0][0]']
#
#  conv2d_772 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_771[0][0]']
#
#  conv2d_775 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_774[0][0]']
#
#  batch_normalization_772 (Batch  (None, 18, 18, 160)  640        ['conv2d_772[0][0]']
#  Normalization)
#
#  batch_normalization_775 (Batch  (None, 18, 18, 160)  640        ['conv2d_775[0][0]']
#  Normalization)
#
#  activation_772 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_772[0][0]']
#
#  activation_775 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_775[0][0]']
#
#  average_pooling2d_84 (AverageP  (None, 18, 18, 768)  0          ['concatenate_97[0][0]']
#  ooling2D)
#
#  conv2d_773 (Conv2D)            (None, 18, 18, 192)  215232      ['activation_772[0][0]']
#
#  conv2d_776 (Conv2D)            (None, 18, 18, 192)  215232      ['activation_775[0][0]']
#
#  conv2d_777 (Conv2D)            (None, 18, 18, 192)  147648      ['average_pooling2d_84[0][0]']
#
#  conv2d_778 (Conv2D)            (None, 18, 18, 192)  147648      ['concatenate_97[0][0]']
#
#  batch_normalization_773 (Batch  (None, 18, 18, 192)  768        ['conv2d_773[0][0]']
#  Normalization)
#
#  batch_normalization_776 (Batch  (None, 18, 18, 192)  768        ['conv2d_776[0][0]']
#  Normalization)
#
#  batch_normalization_777 (Batch  (None, 18, 18, 192)  768        ['conv2d_777[0][0]']
#  Normalization)
#
#  batch_normalization_778 (Batch  (None, 18, 18, 192)  768        ['conv2d_778[0][0]']
#  Normalization)
#
#  activation_773 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_773[0][0]']
#
#  activation_776 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_776[0][0]']
#
#  activation_777 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_777[0][0]']
#
#  activation_778 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_778[0][0]']
#
#  concatenate_98 (Concatenate)   (None, 18, 18, 768)  0           ['activation_773[0][0]',
#                                                                   'activation_776[0][0]',
#                                                                   'activation_777[0][0]',
#                                                                   'activation_778[0][0]']
#
#  conv2d_779 (Conv2D)            (None, 18, 18, 160)  123040      ['concatenate_98[0][0]']
#
#  batch_normalization_779 (Batch  (None, 18, 18, 160)  640        ['conv2d_779[0][0]']
#  Normalization)
#
#  activation_779 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_779[0][0]']
#
#  conv2d_780 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_779[0][0]']
#
#  batch_normalization_780 (Batch  (None, 18, 18, 160)  640        ['conv2d_780[0][0]']
#  Normalization)
#
#  activation_780 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_780[0][0]']
#
#  conv2d_781 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_780[0][0]']
#
#  conv2d_784 (Conv2D)            (None, 18, 18, 160)  123040      ['concatenate_98[0][0]']
#
#  batch_normalization_781 (Batch  (None, 18, 18, 160)  640        ['conv2d_781[0][0]']
#  Normalization)
#
#  batch_normalization_784 (Batch  (None, 18, 18, 160)  640        ['conv2d_784[0][0]']
#  Normalization)
#
#  activation_781 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_781[0][0]']
#
#  activation_784 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_784[0][0]']
#
#  conv2d_782 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_781[0][0]']
#
#  conv2d_785 (Conv2D)            (None, 18, 18, 160)  179360      ['activation_784[0][0]']
#
#  batch_normalization_782 (Batch  (None, 18, 18, 160)  640        ['conv2d_782[0][0]']
#  Normalization)
#
#  batch_normalization_785 (Batch  (None, 18, 18, 160)  640        ['conv2d_785[0][0]']
#  Normalization)
#
#  activation_782 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_782[0][0]']
#
#  activation_785 (Activation)    (None, 18, 18, 160)  0           ['batch_normalization_785[0][0]']
#
#  average_pooling2d_85 (AverageP  (None, 18, 18, 768)  0          ['concatenate_98[0][0]']
#  ooling2D)
#
#  conv2d_783 (Conv2D)            (None, 18, 18, 192)  215232      ['activation_782[0][0]']
#
#  conv2d_786 (Conv2D)            (None, 18, 18, 192)  215232      ['activation_785[0][0]']
#
#  conv2d_787 (Conv2D)            (None, 18, 18, 192)  147648      ['average_pooling2d_85[0][0]']
#
#  conv2d_788 (Conv2D)            (None, 18, 18, 192)  147648      ['concatenate_98[0][0]']
#
#  batch_normalization_783 (Batch  (None, 18, 18, 192)  768        ['conv2d_783[0][0]']
#  Normalization)
#
#  batch_normalization_786 (Batch  (None, 18, 18, 192)  768        ['conv2d_786[0][0]']
#  Normalization)
#
#  batch_normalization_787 (Batch  (None, 18, 18, 192)  768        ['conv2d_787[0][0]']
#  Normalization)
#
#  batch_normalization_788 (Batch  (None, 18, 18, 192)  768        ['conv2d_788[0][0]']
#  Normalization)
#
#  activation_783 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_783[0][0]']
#
#  activation_786 (Activation)    (None, 18, 18, 192)  0           ['batch_normalization_786[0][0]']
#
# ...
#
#  conv2d_811 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_810[0][0]']
#
#  conv2d_812 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_810[0][0]']
#
#  average_pooling2d_88 (AverageP  (None, 8, 8, 1280)  0           ['concatenate_101[0][0]']
#  ooling2D)
#
#  batch_normalization_808 (Batch  (None, 8, 8, 384)   1536        ['conv2d_808[0][0]']
#  Normalization)
#
#  batch_normalization_809 (Batch  (None, 8, 8, 384)   1536        ['conv2d_809[0][0]']
#  Normalization)
#
#  batch_normalization_811 (Batch  (None, 8, 8, 384)   1536        ['conv2d_811[0][0]']
#  Normalization)
#
#  batch_normalization_812 (Batch  (None, 8, 8, 384)   1536        ['conv2d_812[0][0]']
#  Normalization)
#
#  conv2d_813 (Conv2D)            (None, 8, 8, 192)    245952      ['average_pooling2d_88[0][0]']
#
#  conv2d_814 (Conv2D)            (None, 8, 8, 320)    409920      ['concatenate_101[0][0]']
#
#  activation_808 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_808[0][0]']
#
#  activation_809 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_809[0][0]']
#
#  activation_811 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_811[0][0]']
#
#  activation_812 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_812[0][0]']
#
#  batch_normalization_813 (Batch  (None, 8, 8, 192)   768         ['conv2d_813[0][0]']
#  Normalization)
#
#  batch_normalization_814 (Batch  (None, 8, 8, 320)   1280        ['conv2d_814[0][0]']
#  Normalization)
#
#  concatenate_102 (Concatenate)  (None, 8, 8, 768)    0           ['activation_808[0][0]',
#                                                                   'activation_809[0][0]']
#
#  concatenate_103 (Concatenate)  (None, 8, 8, 768)    0           ['activation_811[0][0]',
#                                                                   'activation_812[0][0]']
#
#  activation_813 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_813[0][0]']
#
#  activation_814 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_814[0][0]']
#
#  concatenate_104 (Concatenate)  (None, 8, 8, 2048)   0           ['concatenate_102[0][0]',
#                                                                   'concatenate_103[0][0]',
#                                                                   'activation_813[0][0]',
#                                                                   'activation_814[0][0]']
#
#  conv2d_815 (Conv2D)            (None, 8, 8, 448)    917952      ['concatenate_104[0][0]']
#
#  batch_normalization_815 (Batch  (None, 8, 8, 448)   1792        ['conv2d_815[0][0]']
#  Normalization)
#
#  activation_815 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_815[0][0]']
#
#  conv2d_816 (Conv2D)            (None, 8, 8, 384)    1548672     ['activation_815[0][0]']
#
#  conv2d_819 (Conv2D)            (None, 8, 8, 384)    786816      ['concatenate_104[0][0]']
#
#  batch_normalization_816 (Batch  (None, 8, 8, 384)   1536        ['conv2d_816[0][0]']
#  Normalization)
#
#  batch_normalization_819 (Batch  (None, 8, 8, 384)   1536        ['conv2d_819[0][0]']
#  Normalization)
#
#  activation_816 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_816[0][0]']
#
#  activation_819 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_819[0][0]']
#
#  conv2d_817 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_816[0][0]']
#
#  conv2d_818 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_816[0][0]']
#
#  conv2d_820 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_819[0][0]']
#
#  conv2d_821 (Conv2D)            (None, 8, 8, 384)    442752      ['activation_819[0][0]']
#
#  average_pooling2d_89 (AverageP  (None, 8, 8, 2048)  0           ['concatenate_104[0][0]']
#  ooling2D)
#
#  batch_normalization_817 (Batch  (None, 8, 8, 384)   1536        ['conv2d_817[0][0]']
#  Normalization)
#
#  batch_normalization_818 (Batch  (None, 8, 8, 384)   1536        ['conv2d_818[0][0]']
#  Normalization)
#
#  batch_normalization_820 (Batch  (None, 8, 8, 384)   1536        ['conv2d_820[0][0]']
#  Normalization)
#
#  batch_normalization_821 (Batch  (None, 8, 8, 384)   1536        ['conv2d_821[0][0]']
#  Normalization)
#
#  conv2d_822 (Conv2D)            (None, 8, 8, 192)    393408      ['average_pooling2d_89[0][0]']
#
#  conv2d_823 (Conv2D)            (None, 8, 8, 320)    655680      ['concatenate_104[0][0]']
#
#  average_pooling2d_87 (AverageP  (None, 5, 5, 768)   0           ['concatenate_100[0][0]']
#  ooling2D)
#
#  activation_817 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_817[0][0]']
#
#  activation_818 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_818[0][0]']
#
#  activation_820 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_820[0][0]']
#
#  activation_821 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_821[0][0]']
#
#  batch_normalization_822 (Batch  (None, 8, 8, 192)   768         ['conv2d_822[0][0]']
#  Normalization)
#
#  batch_normalization_823 (Batch  (None, 8, 8, 320)   1280        ['conv2d_823[0][0]']
#  Normalization)
#
#  conv2d_799 (Conv2D)            (None, 5, 5, 128)    98432       ['average_pooling2d_87[0][0]']
#
#  concatenate_105 (Concatenate)  (None, 8, 8, 768)    0           ['activation_817[0][0]',
#                                                                   'activation_818[0][0]']
#
#  concatenate_106 (Concatenate)  (None, 8, 8, 768)    0           ['activation_820[0][0]',
#                                                                   'activation_821[0][0]']
#
#  activation_822 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_822[0][0]']
#
#  activation_823 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_823[0][0]']
#
#  batch_normalization_799 (Batch  (None, 5, 5, 128)   512         ['conv2d_799[0][0]']
#  Normalization)
#
#  concatenate_107 (Concatenate)  (None, 8, 8, 2048)   0           ['concatenate_105[0][0]',
#                                                                   'concatenate_106[0][0]',
#                                                                   'activation_822[0][0]',
#                                                                   'activation_823[0][0]']
#
#  activation_799 (Activation)    (None, 5, 5, 128)    0           ['batch_normalization_799[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 2048)        0           ['concatenate_107[0][0]']
#  obalAveragePooling2D)
#
#  flatten_3 (Flatten)            (None, 3200)         0           ['activation_799[0][0]']
#
#  dense_14 (Dense)               (None, 2048)         4196352     ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 768)          2458368     ['flatten_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 2048)         0           ['dense_14[0][0]']
#
#  dropout_6 (Dropout)            (None, 768)          0           ['dense_12[0][0]']
#
#  dense_15 (Dense)               (None, 1000)         2049000     ['dropout_7[0][0]']
#
#  dense_13 (Dense)               (None, 34)           26146       ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 30,518,570
# Trainable params: 30,483,882
# Non-trainable params: 34,688
# __________________________________________________________________________________________________

# %% [markdown]
# #### Generating Graph of the Inception Model

# %%
tf.keras.utils.plot_model(model, to_file="inceptionv3.pdf", show_shapes=True)

# %% [markdown]
# ## Data Processing and Model Training

# %%
data_dir = "/kaggle/input/wafer-dataset-new/Dataset"

# %% [markdown]
# ### Training and Validation Data Generators

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset="training",
    label_mode='categorical',
    seed=123,
    image_size=(229, 229),
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    label_mode='categorical',
    seed=123,
    image_size=(229, 229),
    batch_size=32
)

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
norm_train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
norm_val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE
norm_train_ds = norm_train_ds.cache().prefetch(buffer_size=AUTOTUNE)
norm_val_ds = norm_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=10,
        verbose=1
    )
]

# %%
import time
start = time.time()
with tf.device('/gpu:0'):
    model_inception = model.fit(
        norm_train_ds,
        validation_data=norm_val_ds,
        epochs=40,
    )
stop = time.time()
print(f'Training on GPU took: {(stop-start)/60} minutes')

# %%
print(model.history.keys())

plt.figure(figsize=(12, 10))

# summarize history for accuracy
plt.subplot(2, 1, 1)
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# summarize history for loss
plt.subplot(2, 1, 2)
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model_inception.evaluate(norm_val_ds)
